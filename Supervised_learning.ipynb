# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Удаляем-лишние-признаки" data-toc-modified-id="Удаляем-лишние-признаки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Удаляем лишние признаки</a></span></li><li><span><a href="#Разбивка-выборки" data-toc-modified-id="Разбивка-выборки-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Разбивка выборки</a></span></li><li><span><a href="#Кодирование-категориальных-признаков-и-масштабирование-(тренировачная-выборка)" data-toc-modified-id="Кодирование-категориальных-признаков-и-масштабирование-(тренировачная-выборка)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Кодирование категориальных признаков и масштабирование (тренировачная выборка)</a></span></li><li><span><a href="#Кодирование-категориальных-признаков-и-масштабирование-(тестовая-выборка)" data-toc-modified-id="Кодирование-категориальных-признаков-и-масштабирование-(тестовая-выборка)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Кодирование категориальных признаков и масштабирование (тестовая выборка)</a></span></li><li><span><a href="#Кодирование-категориальных-признаков-и-масштабирование-(валидизационная-выборка)" data-toc-modified-id="Кодирование-категориальных-признаков-и-масштабирование-(валидизационная-выборка)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Кодирование категориальных признаков и масштабирование (валидизационная выборка)</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов" data-toc-modified-id="Взвешивание-классов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Взвешивание классов</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Увеличение выборки</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Изменение-порога" data-toc-modified-id="Изменение-порога-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Изменение порога</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span><ul class="toc-item"><li><span><a href="#Без-баланса-классов" data-toc-modified-id="Без-баланса-классов-3.3.1.1"><span class="toc-item-num">3.3.1.1&nbsp;&nbsp;</span>Без баланса классов</a></span></li></ul></li><li><span><a href="#C-балансом-классов" data-toc-modified-id="C-балансом-классов-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>C балансом классов</a></span></li><li><span><a href="#На-увеличенной-выборке" data-toc-modified-id="На-увеличенной-выборке-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>На увеличенной выборке</a></span></li><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Решающее дерево</a></span><ul class="toc-item"><li><span><a href="#Без-баланса-классов" data-toc-modified-id="Без-баланса-классов-3.3.4.1"><span class="toc-item-num">3.3.4.1&nbsp;&nbsp;</span>Без баланса классов</a></span></li><li><span><a href="#С-балансом-классов" data-toc-modified-id="С-балансом-классов-3.3.4.2"><span class="toc-item-num">3.3.4.2&nbsp;&nbsp;</span>С балансом классов</a></span></li><li><span><a href="#На-увеличенной-выборке" data-toc-modified-id="На-увеличенной-выборке-3.3.4.3"><span class="toc-item-num">3.3.4.3&nbsp;&nbsp;</span>На увеличенной выборке</a></span></li></ul></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>Случайный лес</a></span><ul class="toc-item"><li><span><a href="#Без-баланса-классов" data-toc-modified-id="Без-баланса-классов-3.3.5.1"><span class="toc-item-num">3.3.5.1&nbsp;&nbsp;</span>Без баланса классов</a></span></li><li><span><a href="#C-балансом-классов" data-toc-modified-id="C-балансом-классов-3.3.5.2"><span class="toc-item-num">3.3.5.2&nbsp;&nbsp;</span>C балансом классов</a></span></li><li><span><a href="#На-увеличенной-выборке" data-toc-modified-id="На-увеличенной-выборке-3.3.5.3"><span class="toc-item-num">3.3.5.3&nbsp;&nbsp;</span>На увеличенной выборке</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Тестирование-решающего-дерева" data-toc-modified-id="Тестирование-решающего-дерева-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Тестирование решающего дерева</a></span></li><li><span><a href="#Тестирование-случайного-леса" data-toc-modified-id="Тестирование-случайного-леса-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Тестирование случайного леса</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
#     RowNumber — индекс строки в данных
#     CustomerId — уникальный идентификатор клиента
#     Surname — фамилия
#     CreditScore — кредитный рейтинг
#     Geography — страна проживания
#     Gender — пол
#     Age — возраст
#     Tenure — сколько лет человек является клиентом банка
#     Balance — баланс на счёте
#     NumOfProducts — количество продуктов банка, используемых клиентом
#     HasCrCard — наличие кредитной карты
#     IsActiveMember — активность клиента
#     EstimatedSalary — предполагаемая зарплата

# %% [markdown]
# ## Подготовка данных

# %%
# !pip install scikit-learn==1.1.3

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from joblib import dump
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    roc_auc_score,
    mean_absolute_error,
    mean_squared_error,
    roc_curve,
    precision_score,
    recall_score
)
from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler
)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('/datasets/Churn.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df[df['Tenure'].isna()].head(2)
# Out:
#     RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 30         31    15589475  Azikiwe          591     Spain  Female   39
# 48         49    15766205      Yin          550   Germany    Male   38
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 30     NaN       0.00              3          1               0
# 48     NaN  103391.38              1          0               1
#
#     EstimatedSalary  Exited
# 30        140469.38       1
# 48         90878.13       0

# %%
df['Tenure'].unique()
# Out:
# array([ 2.,  1.,  8.,  7.,  4.,  6.,  3., 10.,  5.,  9.,  0., nan])

# %%
df['Tenure']=df['Tenure'].fillna(df['Tenure'].median())

# %% [markdown]
# выводы:
# - Пропуски есть только в одном столбце. Причины не ясны. Заменены на медиану.
# - Данные категориальные, имеет смысл их перекодировать.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Удаляем лишние признаки

# %%
df_new=df[['CreditScore','Geography','Gender','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary','Exited']]

# %% [markdown]
# ### Разбивка выборки

# %%
features_train, features_valid = train_test_split(df_new, test_size=0.4, random_state=12345)
features_valid,features_test = train_test_split(features_valid, test_size=0.5, random_state=12345)

# %% [markdown]
# ### Кодирование категориальных признаков и масштабирование (тренировачная выборка)

# %%
encoder_ohe = OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False)
encoder_ohe.fit(features_train[['Geography','Gender']])
pd.options.mode.chained_assignment = None
features_train[
    encoder_ohe.get_feature_names_out()
] = encoder_ohe.transform(features_train[['Geography','Gender']])
features_train = features_train.drop(['Geography','Gender'], axis=1)
scaler = StandardScaler()
numeric = ['CreditScore','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary','Geography_Germany','Geography_Spain','Gender_Male']
features_train[numeric] = scaler.fit_transform(features_train[numeric])
features_train.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 7479    -0.886751 -0.373192  1.082277  1.232271      -0.891560   0.642466
# 3411     0.608663 -0.183385  1.082277  0.600563      -0.891560  -1.556504
# 6027     2.052152  0.480939 -0.737696  1.027098       0.830152  -1.556504
# 1247    -1.457915 -1.417129  0.354288 -1.233163       0.830152   0.642466
# 3716     0.130961 -1.132419 -1.101690  1.140475      -0.891560  -1.556504
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 7479       -1.055187        -0.187705       0          -0.572475
# 3411       -1.055187        -0.333945       0          -0.572475
# 6027        0.947699         1.503095       0           1.746802
# 1247       -1.055187        -1.071061       0          -0.572475
# 3716       -1.055187         1.524268       0           1.746802
#
#       Geography_Spain  Gender_Male
# 7479         1.728977     0.907278
# 3411        -0.578377    -1.102198
# ...

# %% [markdown]
# ### Кодирование категориальных признаков и масштабирование (тестовая выборка)

# %%
features_test[
    encoder_ohe.get_feature_names_out()
] = encoder_ohe.transform(features_test[['Geography','Gender']])
features_test = features_test.drop(['Geography','Gender'], axis=1)
features_test[numeric] = scaler.fit_transform(features_test[numeric])
features_test.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 7041    -2.152343 -0.088115 -1.104565 -1.195546       0.777708   0.655433
# 5709    -0.044761  0.010780  1.418096 -1.195546      -0.948613   0.655433
# 7117    -0.863239 -0.780381 -0.023425  0.734471      -0.948613   0.655433
# 7775    -0.208456  0.109675  1.778477 -1.195546       0.777708   0.655433
# 8735     0.814642 -0.879276  1.778477  0.629177      -0.948613  -1.525709
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 7041       -0.995012         0.639115       0          -0.581199
# 5709       -0.995012        -1.722312       0          -0.581199
# 7117        1.005013        -1.426223       1          -0.581199
# 7775       -0.995012         0.053240       0          -0.581199
# 8735        1.005013        -1.120569       0          -0.581199
#
#       Geography_Spain  Gender_Male
# 7041        -0.580429     0.899065
# 5709        -0.580429    -1.112266
# ...

# %% [markdown]
# ### Кодирование категориальных признаков и масштабирование (валидизационная выборка)

# %%
features_valid[
    encoder_ohe.get_feature_names_out()
] = encoder_ohe.transform(features_valid[['Geography','Gender']])
features_valid = features_valid.drop(['Geography','Gender'], axis=1)
features_valid[numeric] = scaler.fit_transform(features_valid[numeric])
features_valid.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 8532    -0.643740 -0.366305 -1.024334 -1.235001       0.772118   0.647647
# 5799    -0.229103  0.567908 -0.664224 -1.235001      -0.936108   0.647647
# 5511     0.206266 -0.646569 -1.744555  0.421977      -0.936108   0.647647
# 7365    -0.819960 -0.272884  1.856549  1.216012      -0.936108   0.647647
# 7367    -0.426055  0.287644  1.856549 -1.235001       0.772118   0.647647
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 8532       -0.995012        -0.043299       1          -0.595060
# 5799        1.005013         1.439245       1          -0.595060
# 5511       -0.995012        -1.391276       0           1.680503
# 7365        1.005013        -0.812386       1          -0.595060
# 7367       -0.995012         1.326385       0          -0.595060
#
#       Geography_Spain  Gender_Male
# 8532        -0.553476    -1.061913
# 5799        -0.553476    -1.061913
# ...

# %%
df_new = features_train
df_new = df_new.append(features_test)
df_new = df_new.append(features_valid)

# %%
sns.set(font_scale=1.0)
plt.figure(figsize=(15,10))
sns.heatmap(
    df_new.corr(),
    cmap='RdBu_r',
    annot=True,
    vmin=-1, vmax=1);

# %%
sns.set_style('darkgrid')
sns.set(font_scale=1.3)
sns.pairplot(data=df_new,hue='Exited')

# %%
df_new['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# выводы:
# - Все параметры имеют нормальное распределение
# - Виден дисбаланс классов.

# %% [markdown]
# ## Борьба с дисбалансом

# %%
target_train = features_train['Exited']
target_valid = features_valid['Exited']
target_test  = features_test['Exited']
features_train = features_train.drop(['Exited'],axis=1)
features_test  = features_test.drop(['Exited'],axis=1)
features_valid = features_valid.drop(['Exited'],axis=1)

# %% [markdown]
# ### Взвешивание классов

# %% [markdown]
# #### Логистическая регрессия

# %%
Logistic_model_1 = LogisticRegression(random_state=12345, solver='liblinear')
Logistic_model_1.fit(features_train, target_train)
predicted_valid_Logistic_model_1 = Logistic_model_1.predict(features_valid)
print("F1:", f1_score(target_valid, predicted_valid_Logistic_model_1 ).round(3))
# Out:
# F1: 0.31

# %%
Logistic_model_1_balanced = LogisticRegression(random_state=12345, solver='liblinear',class_weight='balanced')
Logistic_model_1_balanced.fit(features_train, target_train)
predicted_valid_Logistic_model_1_balanced = Logistic_model_1_balanced.predict(features_valid)
print("F1:", f1_score(target_valid, predicted_valid_Logistic_model_1_balanced).round(3))
# Out:
# F1: 0.493

# %% [markdown]
# #### Решающее дерево

# %%
best_model = None
best_result = 0
best_depth = 0
for depth in range(1, 50):
    model_1 = DecisionTreeClassifier(random_state=12345,max_depth=depth)
    model_1.fit(features_train,target_train)
    predictions_valid_1 = model_1.predict(features_valid)
    result = f1_score(target_valid, predictions_valid_1).round(3)

    if result > best_result:
        best_model_1 = model_1
        best_result = result
        best_depth = depth
print("F1 лучшей модели:", best_result)
print("Губина:",best_depth)
# Out:
# F1 лучшей модели: 0.568
# Губина: 6

# %%
best_model = None
best_result = 0
best_depth = 0
for depth in range(1, 50):
    model_1 = DecisionTreeClassifier(random_state=12345,max_depth=depth,class_weight='balanced')
    model_1.fit(features_train,target_train)
    predictions_valid_1 = model_1.predict(features_valid)
    result = f1_score(target_valid, predictions_valid_1).round(3)

    if result > best_result:
        best_model_1 = model_1
        best_result = result
        best_depth = depth
print("F1 лучшей модели:", best_result)
print("Губина:",best_depth)
# Out:
# F1 лучшей модели: 0.596
# Губина: 5

# %% [markdown]
# #### Случайный лес

# %%
best_Forest = None
best_result = 0
for est in range(10, 151, 10):
    for depth in range(1, 16):
        model_3 = RandomForestClassifier(random_state=12345, n_estimators=est, max_depth=depth)
        model_3.fit(features_train,target_train)
        predicted_valid_model_3 = model_3.predict(features_valid)
        result = f1_score(target_valid, predicted_valid_model_3).round(3)
        if result > best_result:
            best_Forest =  est
            best_result = result
            best_depth = depth
print("F1 наилучшей модели:", best_result)
print("best_Forest ", best_Forest )
print("best_depth ", best_depth )
# Out:
# F1 наилучшей модели: 0.597
# best_Forest  16
# best_depth  15

# %%
best_Forest = None
best_result = 0
for est in range(10, 151, 10):
    for depth in range(1, 16):
        model_3 = RandomForestClassifier(random_state=12345, n_estimators=est, max_depth=depth,class_weight='balanced')
        model_3.fit(features_train,target_train)
        predicted_valid_model_3 = model_3.predict(features_valid)
        result = f1_score(target_valid, predicted_valid_model_3).round(3)
        if result > best_result:
            best_Forest =  est
            best_result = result
            best_depth = depth
print("F1 наилучшей модели:", best_result)
print("best_Forest ", best_Forest )
print("best_depth ", best_depth )
# Out:
# F1 наилучшей модели: 0.629
# best_Forest  150
# best_depth  8

# %% [markdown]
# ### Увеличение выборки

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)

    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)

    return features_upsampled, target_upsampled

# %%
features_upsampled, target_upsampled = upsample(features_train, target_train, 4)

# %%
#!pip install imblearn

# %%
#from imblearn.over_sampling import SMOTE

# %%
#oversample = SMOTE(random_state=RANDOM_STATE)

#features_train_up, target_train_up = oversample.fit_resample(features_train_enc, target_train)

# %% [markdown]
# #### Логистическая регрессия

# %%
Logistic_model_2 = LogisticRegression(random_state=12345, solver='liblinear')
Logistic_model_2.fit(features_upsampled, target_upsampled)
predicted_valid_Logistic_model_2 = Logistic_model_2.predict(features_valid)
print("F1:", f1_score(target_valid, predicted_valid_Logistic_model_2).round(3))
# Out:
# F1: 0.493

# %% [markdown]
# #### Решающее дерево

# %%
best_model = None
best_result = 0
best_depth = 0
for depth in range(1, 50):
    model_1 = DecisionTreeClassifier(random_state=12345,max_depth=depth)
    model_1.fit(features_upsampled, target_upsampled)
    predictions_valid_1 = model_1.predict(features_valid)
    result = f1_score(target_valid, predictions_valid_1).round(3)

    if result > best_result:
        best_model_1 = model_1
        best_result = result
        best_depth = depth
print("F1 наилучшей модели:", best_result)
print("Губина:",best_depth)
# Out:
# F1 наилучшей модели: 0.596
# Губина: 5

# %% [markdown]
# ####  Случайный лес

# %%
best_Forest = None
best_result = 0
for est in range(10, 151, 10):
    for depth in range(1, 16):
        model_3 = RandomForestClassifier(random_state=12345, n_estimators=est, max_depth=depth)
        model_3.fit(features_upsampled, target_upsampled)
        predicted_valid_model_3 = model_3.predict(features_valid)
        result = f1_score(target_valid, predicted_valid_model_3).round(3)
        if result > best_result:
            best_Forest =  est
            best_result = result
            best_depth = depth
print("F1 наилучшей модели:", best_result)
print("best_Forest ", best_Forest )
print("best_depth ", best_depth )
# Out:
# F1 наилучшей модели: 0.63
# best_Forest  70
# best_depth  9

# %% [markdown]
# ### Изменение порога

# %% [markdown]
# #### Логистическая регрессия

# %% [markdown]
# ##### Без баланса классов

# %%
Logistic_model_3 = LogisticRegression(random_state=12345,solver='liblinear')
Logistic_model_3.fit(features_upsampled,target_upsampled)
probabilities_valid_3  = Logistic_model_3.predict_proba(features_valid)
probabilities_one_valid_3 = probabilities_valid_3[:, 1]

for threshold in np.arange(0.4, 0.8, 0.05):
    predicted_valid_3 = probabilities_one_valid_3 > threshold
    precision = precision_score(target_valid,predicted_valid_3)
    recall = recall_score(target_valid,predicted_valid_3)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_3).round(2))
# Out:
# Порог = 0.40 | Точность = 0.336, Полнота = 0.797
# F1: 0.47
# Порог = 0.45 | Точность = 0.364, Полнота = 0.722
# F1: 0.48
# Порог = 0.50 | Точность = 0.392, Полнота = 0.665
# F1: 0.49
# Порог = 0.55 | Точность = 0.424, Полнота = 0.598
# F1: 0.5
# Порог = 0.60 | Точность = 0.458, Полнота = 0.545
# F1: 0.5
# Порог = 0.65 | Точность = 0.478, Полнота = 0.452
# F1: 0.46
# Порог = 0.70 | Точность = 0.489, Полнота = 0.356
# F1: 0.41
# Порог = 0.75 | Точность = 0.509, Полнота = 0.278
# F1: 0.36

# %% [markdown]
# #### C балансом классов

# %%
Logistic_model_3_balanced = LogisticRegression(random_state=12345, solver='liblinear',class_weight='balanced')
Logistic_model_3_balanced.fit(features_train, target_train)
probabilities_valid = Logistic_model_3_balanced.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0.4, 0.8, 0.05):
    predicted_valid_2 = probabilities_one_valid > threshold
    precision = precision_score(target_valid,predicted_valid_2)
    recall = recall_score(target_valid,predicted_valid_2)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_2).round(2))
# Out:
# Порог = 0.40 | Точность = 0.336, Полнота = 0.799
# F1: 0.47
# Порог = 0.45 | Точность = 0.363, Полнота = 0.722
# F1: 0.48
# Порог = 0.50 | Точность = 0.392, Полнота = 0.665
# F1: 0.49
# Порог = 0.55 | Точность = 0.424, Полнота = 0.598
# F1: 0.5
# Порог = 0.60 | Точность = 0.455, Полнота = 0.545
# F1: 0.5
# Порог = 0.65 | Точность = 0.478, Полнота = 0.452
# F1: 0.46
# Порог = 0.70 | Точность = 0.489, Полнота = 0.359
# F1: 0.41
# Порог = 0.75 | Точность = 0.506, Полнота = 0.280
# F1: 0.36

# %% [markdown]
# #### На увеличенной выборке

# %%
Logistic_model_2 = LogisticRegression(random_state=12345, solver='liblinear')
Logistic_model_2.fit(features_upsampled, target_upsampled)
probabilities_valid = Logistic_model_2.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0.4, 0.8, 0.05):
    predicted_valid_2 = probabilities_one_valid > threshold
    precision = precision_score(target_valid,predicted_valid_2)
    recall = recall_score(target_valid,predicted_valid_2)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_2).round(2))
# Out:
# Порог = 0.40 | Точность = 0.336, Полнота = 0.797
# F1: 0.47
# Порог = 0.45 | Точность = 0.364, Полнота = 0.722
# F1: 0.48
# Порог = 0.50 | Точность = 0.392, Полнота = 0.665
# F1: 0.49
# Порог = 0.55 | Точность = 0.424, Полнота = 0.598
# F1: 0.5
# Порог = 0.60 | Точность = 0.458, Полнота = 0.545
# F1: 0.5
# Порог = 0.65 | Точность = 0.478, Полнота = 0.452
# F1: 0.46
# Порог = 0.70 | Точность = 0.489, Полнота = 0.356
# F1: 0.41
# Порог = 0.75 | Точность = 0.509, Полнота = 0.278
# F1: 0.36

# %% [markdown]
# #### Решающее дерево

# %% [markdown]
# ##### Без баланса классов

# %%
Decision_model_1 = DecisionTreeClassifier(random_state=12345,max_depth=5)
Decision_model_1.fit(features_train, target_train)
probabilities_valid = Decision_model_1.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0.4, 0.8, 0.05):
    predicted_valid_2 = probabilities_one_valid > threshold
    precision = precision_score(target_valid,predicted_valid_2)
    recall = recall_score(target_valid,predicted_valid_2)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_2).round(2))
# Out:
# Порог = 0.40 | Точность = 0.720, Полнота = 0.493
# F1: 0.59
# Порог = 0.45 | Точность = 0.720, Полнота = 0.493
# F1: 0.59
# Порог = 0.50 | Точность = 0.779, Полнота = 0.414
# F1: 0.54
# Порог = 0.55 | Точность = 0.831, Полнота = 0.364
# F1: 0.51
# Порог = 0.60 | Точность = 0.831, Полнота = 0.364
# F1: 0.51
# Порог = 0.65 | Точность = 0.831, Полнота = 0.364
# F1: 0.51
# Порог = 0.70 | Точность = 0.831, Полнота = 0.364
# F1: 0.51
# Порог = 0.75 | Точность = 0.831, Полнота = 0.364
# F1: 0.51

# %% [markdown]
# ##### С балансом классов

# %%
Decision_model_1_balanced = DecisionTreeClassifier(random_state=12345,class_weight='balanced',max_depth=5)
Decision_model_1_balanced.fit(features_train, target_train)
probabilities_valid = Decision_model_1_balanced.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0.4, 0.8, 0.05):
    predicted_valid_2 = probabilities_one_valid > threshold
    precision = precision_score(target_valid,predicted_valid_2)
    recall = recall_score(target_valid,predicted_valid_2)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_2).round(2))
# Out:
# Порог = 0.40 | Точность = 0.362, Полнота = 0.844
# F1: 0.51
# Порог = 0.45 | Точность = 0.411, Полнота = 0.758
# F1: 0.53
# Порог = 0.50 | Точность = 0.537, Полнота = 0.670
# F1: 0.6
# Порог = 0.55 | Точность = 0.537, Полнота = 0.670
# F1: 0.6
# Порог = 0.60 | Точность = 0.580, Полнота = 0.639
# F1: 0.61
# Порог = 0.65 | Точность = 0.580, Полнота = 0.639
# F1: 0.61
# Порог = 0.70 | Точность = 0.732, Полнота = 0.450
# F1: 0.56
# Порог = 0.75 | Точность = 0.730, Полнота = 0.447
# F1: 0.55

# %% [markdown]
# ##### На увеличенной выборке

# %%
Decision_model_2 = DecisionTreeClassifier(random_state=12345,max_depth=5)
Decision_model_2.fit(features_upsampled, target_upsampled)
probabilities_valid = Decision_model_2.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0.4, 0.8, 0.05):
    predicted_valid_2 = probabilities_one_valid > threshold
    precision = precision_score(target_valid,predicted_valid_2)
    recall = recall_score(target_valid,predicted_valid_2)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_2).round(2))
# Out:
# Порог = 0.40 | Точность = 0.362, Полнота = 0.844
# F1: 0.51
# Порог = 0.45 | Точность = 0.411, Полнота = 0.758
# F1: 0.53
# Порог = 0.50 | Точность = 0.537, Полнота = 0.670
# F1: 0.6
# Порог = 0.55 | Точность = 0.537, Полнота = 0.670
# F1: 0.6
# Порог = 0.60 | Точность = 0.580, Полнота = 0.639
# F1: 0.61
# Порог = 0.65 | Точность = 0.580, Полнота = 0.639
# F1: 0.61
# Порог = 0.70 | Точность = 0.732, Полнота = 0.450
# F1: 0.56
# Порог = 0.75 | Точность = 0.764, Полнота = 0.419
# F1: 0.54

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# ##### Без баланса классов

# %%
Forest_model_1= RandomForestClassifier(random_state=12345,n_estimators=30,max_depth=12)
Forest_model_1.fit(features_train,target_train)
probabilities_valid = Forest_model_1.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0.4, 0.8, 0.05):
    predicted_valid_2 = probabilities_one_valid > threshold
    precision = precision_score(target_valid,predicted_valid_2)
    recall = recall_score(target_valid,predicted_valid_2)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_2).round(2))
# Out:
# Порог = 0.40 | Точность = 0.701, Полнота = 0.538
# F1: 0.61
# Порог = 0.45 | Точность = 0.751, Полнота = 0.498
# F1: 0.6
# Порог = 0.50 | Точность = 0.775, Полнота = 0.462
# F1: 0.58
# Порог = 0.55 | Точность = 0.815, Полнота = 0.411
# F1: 0.55
# Порог = 0.60 | Точность = 0.858, Полнота = 0.390
# F1: 0.54
# Порог = 0.65 | Точность = 0.884, Полнота = 0.366
# F1: 0.52
# Порог = 0.70 | Точность = 0.899, Полнота = 0.321
# F1: 0.47
# Порог = 0.75 | Точность = 0.919, Полнота = 0.244
# F1: 0.39

# %% [markdown]
# ##### C балансом классов

# %%
Forest_model_1_balanced = RandomForestClassifier(random_state=12345,n_estimators=150,class_weight='balanced',max_depth=8)
Forest_model_1_balanced.fit(features_train,target_train)
probabilities_valid = Forest_model_1_balanced.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0.4, 0.8, 0.05):
    predicted_valid_2 = probabilities_one_valid > threshold
    precision = precision_score(target_valid,predicted_valid_2)
    recall = recall_score(target_valid,predicted_valid_2)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_2).round(2))
# Out:
# Порог = 0.40 | Точность = 0.477, Полнота = 0.811
# F1: 0.6
# Порог = 0.45 | Точность = 0.522, Полнота = 0.737
# F1: 0.61
# Порог = 0.50 | Точность = 0.581, Полнота = 0.684
# F1: 0.63
# Порог = 0.55 | Точность = 0.632, Полнота = 0.629
# F1: 0.63
# Порог = 0.60 | Точность = 0.687, Полнота = 0.562
# F1: 0.62
# Порог = 0.65 | Точность = 0.734, Полнота = 0.495
# F1: 0.59
# Порог = 0.70 | Точность = 0.774, Полнота = 0.426
# F1: 0.55
# Порог = 0.75 | Точность = 0.853, Полнота = 0.361
# F1: 0.51

# %% [markdown]
# ##### На увеличенной выборке

# %%
Forest_model_1_balanced = RandomForestClassifier(random_state=12345,n_estimators=70,max_depth=9)
Forest_model_1_balanced.fit(features_upsampled, target_upsampled)
probabilities_valid = Forest_model_1_balanced.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0.6, 0.8, 0.05):
    predicted_valid_2 = probabilities_one_valid > threshold
    precision = precision_score(target_valid,predicted_valid_2)
    recall = recall_score(target_valid,predicted_valid_2)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(
        threshold, precision, recall))
    print("F1:", f1_score(target_valid, predicted_valid_2).round(2))
# Out:
# Порог = 0.40 | Точность = 0.461, Полнота = 0.787
# F1: 0.58
# Порог = 0.45 | Точность = 0.505, Полнота = 0.742
# F1: 0.6
# Порог = 0.50 | Точность = 0.571, Полнота = 0.703
# F1: 0.63
# Порог = 0.55 | Точность = 0.600, Полнота = 0.644
# F1: 0.62
# Порог = 0.60 | Точность = 0.663, Полнота = 0.579
# F1: 0.62
# Порог = 0.65 | Точность = 0.706, Полнота = 0.522
# F1: 0.6
# Порог = 0.70 | Точность = 0.770, Полнота = 0.464
# F1: 0.58
# Порог = 0.75 | Точность = 0.821, Полнота = 0.407
# F1: 0.54

# %% [markdown]
# Выводы:
# - Балансировка классов дает хороший результат на всех моделях и увеличивает F1 меру
# - Увеличение выборки тоже улучшает результаты всех моделей
# - Сдвиг порога дает увеичение к F1,но не понятн чего мы на самом деле хотим в смысле полноты и точности.
#
# Результаты на валидационной выборке:
# - Логистическая регрессия:
#     - F1 с взвешиванием   = 0.49
#     - F1 upsample        = 0.496
# - Решающее дерево(глубина 5):
#     - F1 с взвешиванием   = 0.596
#     - F1 upsample         = 0.596
# - Случайный лес:
#     - F1 с взвешиванием (глубина 8, деревьев 150)  = 0.629
#     - F1 upsample  (глубина 9, деревьев 70)        = 0.63
#
#  Логистическу регрессию не имеет смысла тестировать далее.

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# ### Тестирование решающего дерева

# %%
model_Decision_1 = DecisionTreeClassifier(random_state=12345,max_depth=5,class_weight='balanced')
model_Decision_1.fit(features_train,target_train)
predictions_test = model_Decision_1.predict(features_test)
print("F1:", f1_score(target_test, predictions_test).round(3))
probabilities = model_Decision_1.predict_proba(features_test)
probabilities_one_test_model_Decision_1 = probabilities[:, 1]
auc_roc = roc_auc_score(target_test,probabilities_one_test_model_Decision_1)
print("AUC-ROC:",auc_roc.round(3))
# Out:
# F1: 0.581
# AUC-ROC: 0.826

# %%
model_Decision_2 = DecisionTreeClassifier(random_state=12345,max_depth=5)
model_Decision_2.fit(features_upsampled, target_upsampled)
predictions_test_model_Decision_2 = model_Decision_2.predict(features_test)
print("F1:", f1_score(target_test, predictions_test).round(3))
probabilities = model_Decision_2.predict_proba(features_test)
probabilities_one_test_model_Decision_2 = probabilities[:, 1]
auc_roc = roc_auc_score(target_test,probabilities_one_test_model_Decision_2)
print("AUC-ROC:",auc_roc.round(3))
# Out:
# F1: 0.581
# AUC-ROC: 0.826

# %% [markdown]
# ### Тестирование случайного леса

# %%
model_Forest_1 = RandomForestClassifier(random_state=12345, n_estimators=150, max_depth=8,class_weight='balanced')
model_Forest_1.fit(features_train,target_train)
predictions_test_model_Forest_1 = model_Forest_1.predict(features_test)
print("F1:", f1_score(target_test, predictions_test).round(3))
probabilities = model_Forest_1.predict_proba(features_test)
probabilities_one_test_model_Forest_1 = probabilities[:, 1]
auc_roc = roc_auc_score(target_test,probabilities_one_test_model_Forest_1)
print("AUC-ROC:",auc_roc)
# Out:
# F1: 0.581
# AUC-ROC: 0.8563301357726539

# %%
model_Forest_2 = RandomForestClassifier(random_state=12345, n_estimators=70, max_depth=9)
model_Forest_2.fit(features_upsampled, target_upsampled)
predictions_test_model_Forest_2 = model_Forest_2.predict(features_test)
print("F1:", f1_score(target_test, predictions_test_model_Forest_2).round(3))
probabilities = model_Forest_2.predict_proba(features_test)
probabilities_one_test_model_Forest_2 = probabilities[:, 1]
auc_roc = roc_auc_score(target_test,probabilities_one_test_model_Forest_2)
print("AUC-ROC:",auc_roc.round(3))
# Out:
# F1: 0.607
# AUC-ROC: 0.847

# %%
probabilities = model_Forest_2.predict_proba(features_test)
probabilities_one = probabilities[:, 1]
print('Площадь ROC-кривой:', roc_auc_score(target_test, probabilities_one))
# Out:
# Площадь ROC-кривой: 0.8468828655420487

# %%
probabilities_test_model_Forest_2 = model_Forest_2.predict_proba(features_test)
probabilities_one_test_model_Forest_2 = probabilities_test_model_Forest_2[:, 1]
fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test_model_Forest_2)

plt.figure()
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.show()

# %% [markdown]
# выводы:
# - Удалось достичь F1-меры не менее 0.59 для 1 модели
# - Лучшая модель - Случайный лес, 70 деревьев, глубина 9 на выборке, сбалансированной увеличением малого класса.
# - метрика AUC-ROC лучшей модели = 0.85
